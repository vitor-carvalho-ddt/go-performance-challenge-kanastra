# %%
import pandas as pd

import time
import os

# Função para ler o arquivo CSV de maneira otimizada
def read_large_csv(file_path):
    # Usando o parâmetro 'usecols' para carregar apenas as colunas necessárias
    cols_needed = ['NU_DOCUMENTO', 'VALOR_NOMINAL', 'VALOR_PRESENTE', 'VALOR_AQUISICAO']
    df = pd.read_csv(file_path, usecols=cols_needed, sep=";", thousands=",", on_bad_lines='warn')
    df["VALOR_NOMINAL"] = pd.to_numeric(df["VALOR_NOMINAL"])
    df["VALOR_PRESENTE"] = pd.to_numeric(df["VALOR_PRESENTE"])
    df["VALOR_AQUISICAO"] = pd.to_numeric(df["VALOR_AQUISICAO"])
    print(df.head())
    return df

# Função para calcular estatísticas
def calculate_statistics(df, entity_filter=None):
    # Calculando as estatísticas
    stats = df.groupby('NU_DOCUMENTO').agg(
        VALOR_NOMINAL_SUM=('VALOR_NOMINAL', 'sum'),
        VALOR_NOMINAL_AVG=('VALOR_NOMINAL', 'mean'),
        VALOR_NOMINAL_MAX=('VALOR_NOMINAL', 'max'),
        VALOR_NOMINAL_MIN=('VALOR_NOMINAL', 'min'),
        
        VALOR_PRESENTE_SUM=('VALOR_PRESENTE', 'sum'),
        VALOR_PRESENTE_AVG=('VALOR_PRESENTE', 'mean'),
        VALOR_PRESENTE_MAX=('VALOR_PRESENTE', 'max'),
        VALOR_PRESENTE_MIN=('VALOR_PRESENTE', 'min'),
        
        VALOR_AQUISICAO_SUM=('VALOR_AQUISICAO', 'sum'),
        VALOR_AQUISICAO_AVG=('VALOR_AQUISICAO', 'mean'),
        VALOR_AQUISICAO_MAX=('VALOR_AQUISICAO', 'max'),
        VALOR_AQUISICAO_MIN=('VALOR_AQUISICAO', 'min')
    ).reset_index()

    return stats

# Função para salvar as estatísticas em um arquivo CSV
def save_statistics_to_csv(stats_df, output_file):
    stats_df.to_csv(output_file, index=False)
    print(f"Estatísticas salvas em {output_file}")

# Função principal para executar o desafio
def main(input_path, entity_filter=None, output_file="estatisticas_financeiras.csv"):
    output_dir = os.getcwd() + "/output/"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    # Leitura dos dados do arquivo CSV
    start_time = time.time()
    df_lst = []
    for file in os.listdir(input_path):
        if (".csv" in file) and not ("Zone.Identifier" in file):
            file_path = input_path + file
            print(file_path)
            df_lst.append(read_large_csv(file_path))

    df = pd.concat(df_lst)
    print(f"Tempo de leitura dos arquivos: {time.time() - start_time:.2f} segundos")

    # Cálculo das estatísticas
    start_time = time.time()
    stats = calculate_statistics(df, entity_filter)
    print(f"Tempo de cálculo das estatísticas: {time.time() - start_time:.2f} segundos")

    # Salvando as estatísticas em um novo arquivo CSV
    output_file_path = output_dir + output_file
    save_statistics_to_csv(stats, output_file_path)

input_file = os.getcwd() + "/files/"  # Substitua pelo caminho do seu arquivo
main(input_file)
# Out:
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0040 copy.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          30.17            9.93             9.83     109327240
# 1          28.16            7.47             7.39     109327240
# 2          48.70           48.00            47.48     108425838
# 3          58.44           46.39            45.91     108425838
# 4          40.91           26.17            25.90     108425838
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0041 copy.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          26.41           15.18            15.02     110918745
# 1          19.80            9.16             9.07     110918745
# 2          17.35            6.48             6.41     110918745
# 3           8.68            2.61             2.58     110918745
# 4           5.23            0.82             0.81     110918745
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0042 copy 3.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          25.52           10.05             9.95     115122649
# 1          12.75            4.04             4.00     115122649
# 2           6.38            1.63             1.61     115122649
# 3           6.78            0.91             0.90     115122649
# 4          13.98            6.48             6.41     107816680
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0042 copy 2.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          25.52           10.05             9.95     115122649
# 1          12.75            4.04             4.00     115122649
# 2           6.38            1.63             1.61     115122649
# 3           6.78            0.91             0.90     115122649
# 4          13.98            6.48             6.41     107816680
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0039 copy 4.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           7.36            3.34             3.31     113601173
# 1          37.45           31.97            31.64     109675677
# 2          34.96           24.05            23.80     109675677
# 3          21.75           12.05            11.93     109675677
# 4          16.88            4.48             4.43     109666602
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0047 copy 4.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           9.02            2.92             2.89     116679461
# 1          77.23           46.05            45.65     116678411
# 2          38.61           18.54            18.38     116678411
# 3          19.31            7.47             7.41     116678411
# 4          13.38            4.18             4.14     116678411
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0042 copy 4.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          25.52           10.05             9.95     115122649
# 1          12.75            4.04             4.00     115122649
# 2           6.38            1.63             1.61     115122649
# 3           6.78            0.91             0.90     115122649
# 4          13.98            6.48             6.41     107816680
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0047 copy 3.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           9.02            2.92             2.89     116679461
# 1          77.23           46.05            45.65     116678411
# 2          38.61           18.54            18.38     116678411
# 3          19.31            7.47             7.41     116678411
# 4          13.38            4.18             4.14     116678411
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0039 copy 2.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           7.36            3.34             3.31     113601173
# 1          37.45           31.97            31.64     109675677
# 2          34.96           24.05            23.80     109675677
# 3          21.75           12.05            11.93     109675677
# 4          16.88            4.48             4.43     109666602
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0039 copy 3.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           7.36            3.34             3.31     113601173
# 1          37.45           31.97            31.64     109675677
# 2          34.96           24.05            23.80     109675677
# 3          21.75           12.05            11.93     109675677
# 4          16.88            4.48             4.43     109666602
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0047 copy 2.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           9.02            2.92             2.89     116679461
# 1          77.23           46.05            45.65     116678411
# 2          38.61           18.54            18.38     116678411
# 3          19.31            7.47             7.41     116678411
# 4          13.38            4.18             4.14     116678411
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0047.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           9.02            2.92             2.89     116679461
# 1          77.23           46.05            45.65     116678411
# 2          38.61           18.54            18.38     116678411
# 3          19.31            7.47             7.41     116678411
# 4          13.38            4.18             4.14     116678411
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0040 copy 2.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          30.17            9.93             9.83     109327240
# 1          28.16            7.47             7.39     109327240
# 2          48.70           48.00            47.48     108425838
# 3          58.44           46.39            45.91     108425838
# 4          40.91           26.17            25.90     108425838
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0040 copy 3.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          30.17            9.93             9.83     109327240
# 1          28.16            7.47             7.39     109327240
# 2          48.70           48.00            47.48     108425838
# 3          58.44           46.39            45.91     108425838
# 4          40.91           26.17            25.90     108425838
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0046.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          12.20            6.65             6.59     116870271
# 1           6.10            2.67             2.65     116870271
# 2          68.44           65.34            64.79     116629004
# 3          63.88           49.72            49.32     116629004
# 4          46.61           29.59            29.35     116629004
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0044.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          95.67           74.69            73.92     111433146
# 1          66.97           42.14            41.70     111433146
# 2          62.50           31.67            31.34     111433146
# 3          46.88           19.14            18.94     111433146
# 4          23.44            7.71             7.63     111433146
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0045 copy 4.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         306.16          239.04           236.57     107812955
# 1           8.81            2.90             2.87     109218899
# 2           5.01            1.32             1.31     109218899
# 3           5.80            1.24             1.23     109218899
# 4          35.06           29.38            29.08     114775107
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0045.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         306.16          239.04           236.57     107812955
# 1           8.81            2.90             2.87     109218899
# 2           5.01            1.32             1.31     109218899
# 3           5.80            1.24             1.23     109218899
# 4          35.06           29.38            29.08     114775107
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0047 copy.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           9.02            2.92             2.89     116679461
# 1          77.23           46.05            45.65     116678411
# 2          38.61           18.54            18.38     116678411
# 3          19.31            7.47             7.41     116678411
# 4          13.38            4.18             4.14     116678411
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0041.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          26.41           15.18            15.02     110918745
# 1          19.80            9.16             9.07     110918745
# 2          17.35            6.48             6.41     110918745
# 3           8.68            2.61             2.58     110918745
# 4           5.23            0.82             0.81     110918745
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0046 copy.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          12.20            6.65             6.59     116870271
# 1           6.10            2.67             2.65     116870271
# 2          68.44           65.34            64.79     116629004
# 3          63.88           49.72            49.32     116629004
# 4          46.61           29.59            29.35     116629004
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0040 copy 4.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          30.17            9.93             9.83     109327240
# 1          28.16            7.47             7.39     109327240
# 2          48.70           48.00            47.48     108425838
# 3          58.44           46.39            45.91     108425838
# 4          40.91           26.17            25.90     108425838
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_001 copy.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         169.67          101.16            99.94     106096977
# 1          84.84           40.74            40.25     106096977
# 2          55.68           52.08            51.44     106135870
# 3           5.63            1.79             1.77     106135984
# 4         160.27          147.19           145.37     106136007
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0040.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          30.17            9.93             9.83     109327240
# 1          28.16            7.47             7.39     109327240
# 2          48.70           48.00            47.48     108425838
# 3          58.44           46.39            45.91     108425838
# 4          40.91           26.17            25.90     108425838
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0042.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          25.52           10.05             9.95     115122649
# 1          12.75            4.04             4.00     115122649
# 2           6.38            1.63             1.61     115122649
# 3           6.78            0.91             0.90     115122649
# 4          13.98            6.48             6.41     107816680
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0045 copy 2.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         306.16          239.04           236.57     107812955
# 1           8.81            2.90             2.87     109218899
# 2           5.01            1.32             1.31     109218899
# 3           5.80            1.24             1.23     109218899
# 4          35.06           29.38            29.08     114775107
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0045 copy 3.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         306.16          239.04           236.57     107812955
# 1           8.81            2.90             2.87     109218899
# 2           5.01            1.32             1.31     109218899
# 3           5.80            1.24             1.23     109218899
# 4          35.06           29.38            29.08     114775107
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0043.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           8.86            1.45             1.45     117100090
# 1         120.73          119.13           119.03     117100968
# 2           6.97            0.98             0.98     117100968
# 3          20.37            8.79             8.78     117329512
# 4          10.19            3.54             3.54     117329512
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0043 copy 4.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           8.86            1.45             1.45     117100090
# 1         120.73          119.13           119.03     117100968
# 2           6.97            0.98             0.98     117100968
# 3          20.37            8.79             8.78     117329512
# 4          10.19            3.54             3.54     117329512
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0046 copy 3.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          12.20            6.65             6.59     116870271
# 1           6.10            2.67             2.65     116870271
# 2          68.44           65.34            64.79     116629004
# 3          63.88           49.72            49.32     116629004
# 4          46.61           29.59            29.35     116629004
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0046 copy 2.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          12.20            6.65             6.59     116870271
# 1           6.10            2.67             2.65     116870271
# 2          68.44           65.34            64.79     116629004
# 3          63.88           49.72            49.32     116629004
# 4          46.61           29.59            29.35     116629004
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0043 copy 3.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           8.86            1.45             1.45     117100090
# 1         120.73          119.13           119.03     117100968
# 2           6.97            0.98             0.98     117100968
# 3          20.37            8.79             8.78     117329512
# 4          10.19            3.54             3.54     117329512
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0043 copy 2.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           8.86            1.45             1.45     117100090
# 1         120.73          119.13           119.03     117100968
# 2           6.97            0.98             0.98     117100968
# 3          20.37            8.79             8.78     117329512
# 4          10.19            3.54             3.54     117329512
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0043 copy.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           8.86            1.45             1.45     117100090
# 1         120.73          119.13           119.03     117100968
# 2           6.97            0.98             0.98     117100968
# 3          20.37            8.79             8.78     117329512
# 4          10.19            3.54             3.54     117329512
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0042 copy.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          25.52           10.05             9.95     115122649
# 1          12.75            4.04             4.00     115122649
# 2           6.38            1.63             1.61     115122649
# 3           6.78            0.91             0.90     115122649
# 4          13.98            6.48             6.41     107816680
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0046 copy 4.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          12.20            6.65             6.59     116870271
# 1           6.10            2.67             2.65     116870271
# 2          68.44           65.34            64.79     116629004
# 3          63.88           49.72            49.32     116629004
# 4          46.61           29.59            29.35     116629004
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0039.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           7.36            3.34             3.31     113601173
# 1          37.45           31.97            31.64     109675677
# 2          34.96           24.05            23.80     109675677
# 3          21.75           12.05            11.93     109675677
# 4          16.88            4.48             4.43     109666602
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_001 copy 4.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         169.67          101.16            99.94     106096977
# 1          84.84           40.74            40.25     106096977
# 2          55.68           52.08            51.44     106135870
# 3           5.63            1.79             1.77     106135984
# 4         160.27          147.19           145.37     106136007
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0041 copy 4.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          26.41           15.18            15.02     110918745
# 1          19.80            9.16             9.07     110918745
# 2          17.35            6.48             6.41     110918745
# 3           8.68            2.61             2.58     110918745
# 4           5.23            0.82             0.81     110918745
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0039 copy.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           7.36            3.34             3.31     113601173
# 1          37.45           31.97            31.64     109675677
# 2          34.96           24.05            23.80     109675677
# 3          21.75           12.05            11.93     109675677
# 4          16.88            4.48             4.43     109666602
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_001.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         169.67          101.16            99.94     106096977
# 1          84.84           40.74            40.25     106096977
# 2          55.68           52.08            51.44     106135870
# 3           5.63            1.79             1.77     106135984
# 4         160.27          147.19           145.37     106136007
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0044 copy.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          95.67           74.69            73.92     111433146
# 1          66.97           42.14            41.70     111433146
# 2          62.50           31.67            31.34     111433146
# 3          46.88           19.14            18.94     111433146
# 4          23.44            7.71             7.63     111433146
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0045 copy.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         306.16          239.04           236.57     107812955
# 1           8.81            2.90             2.87     109218899
# 2           5.01            1.32             1.31     109218899
# 3           5.80            1.24             1.23     109218899
# 4          35.06           29.38            29.08     114775107
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0044 copy 2.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          95.67           74.69            73.92     111433146
# 1          66.97           42.14            41.70     111433146
# 2          62.50           31.67            31.34     111433146
# 3          46.88           19.14            18.94     111433146
# 4          23.44            7.71             7.63     111433146
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0044 copy 3.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          95.67           74.69            73.92     111433146
# 1          66.97           42.14            41.70     111433146
# 2          62.50           31.67            31.34     111433146
# 3          46.88           19.14            18.94     111433146
# 4          23.44            7.71             7.63     111433146
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_001 copy 2.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         169.67          101.16            99.94     106096977
# 1          84.84           40.74            40.25     106096977
# 2          55.68           52.08            51.44     106135870
# 3           5.63            1.79             1.77     106135984
# 4         160.27          147.19           145.37     106136007
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0041 copy 2.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          26.41           15.18            15.02     110918745
# 1          19.80            9.16             9.07     110918745
# 2          17.35            6.48             6.41     110918745
# 3           8.68            2.61             2.58     110918745
# 4           5.23            0.82             0.81     110918745
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0041 copy 3.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          26.41           15.18            15.02     110918745
# 1          19.80            9.16             9.07     110918745
# 2          17.35            6.48             6.41     110918745
# 3           8.68            2.61             2.58     110918745
# 4           5.23            0.82             0.81     110918745
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_001 copy 3.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         169.67          101.16            99.94     106096977
# 1          84.84           40.74            40.25     106096977
# 2          55.68           52.08            51.44     106135870
# 3           5.63            1.79             1.77     106135984
# 4         160.27          147.19           145.37     106136007
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0044 copy 4.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          95.67           74.69            73.92     111433146
# 1          66.97           42.14            41.70     111433146
# 2          62.50           31.67            31.34     111433146
# 3          46.88           19.14            18.94     111433146
# 4          23.44            7.71             7.63     111433146
# Tempo de leitura dos arquivos: 26.58 segundos
# Tempo de cálculo das estatísticas: 2.08 segundos
# Estatísticas salvas em /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/output/estatisticas_financeiras.csv

# %%
import os
import pandas as pd

input_path = os.getcwd() + "/files/"  # Substitua pelo caminho do seu arquivo

output_dir = os.getcwd() + "/output/"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
# Leitura dos dados do arquivo CSV
df_lst = []
for file in os.listdir(input_path):
    if (".csv" in file) and not ("Zone.Identifier" in file):
        file_path = input_path + file
        print(file_path)
        df_lst.append(read_large_csv(file_path))

df = pd.concat(df_lst)
# Out:
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0047.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           9.02            2.92             2.89     116679461
# 1          77.23           46.05            45.65     116678411
# 2          38.61           18.54            18.38     116678411
# 3          19.31            7.47             7.41     116678411
# 4          13.38            4.18             4.14     116678411
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0046.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          12.20            6.65             6.59     116870271
# 1           6.10            2.67             2.65     116870271
# 2          68.44           65.34            64.79     116629004
# 3          63.88           49.72            49.32     116629004
# 4          46.61           29.59            29.35     116629004
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0044.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          95.67           74.69            73.92     111433146
# 1          66.97           42.14            41.70     111433146
# 2          62.50           31.67            31.34     111433146
# 3          46.88           19.14            18.94     111433146
# 4          23.44            7.71             7.63     111433146
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0045.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         306.16          239.04           236.57     107812955
# 1           8.81            2.90             2.87     109218899
# 2           5.01            1.32             1.31     109218899
# 3           5.80            1.24             1.23     109218899
# 4          35.06           29.38            29.08     114775107
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0041.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          26.41           15.18            15.02     110918745
# 1          19.80            9.16             9.07     110918745
# 2          17.35            6.48             6.41     110918745
# 3           8.68            2.61             2.58     110918745
# 4           5.23            0.82             0.81     110918745
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0040.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          30.17            9.93             9.83     109327240
# 1          28.16            7.47             7.39     109327240
# 2          48.70           48.00            47.48     108425838
# 3          58.44           46.39            45.91     108425838
# 4          40.91           26.17            25.90     108425838
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0042.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0          25.52           10.05             9.95     115122649
# 1          12.75            4.04             4.00     115122649
# 2           6.38            1.63             1.61     115122649
# 3           6.78            0.91             0.90     115122649
# 4          13.98            6.48             6.41     107816680
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0043.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           8.86            1.45             1.45     117100090
# 1         120.73          119.13           119.03     117100968
# 2           6.97            0.98             0.98     117100968
# 3          20.37            8.79             8.78     117329512
# 4          10.19            3.54             3.54     117329512
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_0039.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0           7.36            3.34             3.31     113601173
# 1          37.45           31.97            31.64     109675677
# 2          34.96           24.05            23.80     109675677
# 3          21.75           12.05            11.93     109675677
# 4          16.88            4.48             4.43     109666602
# /Users/vitor.carvalho/Desktop/Workspace/go-performance-challenge-kanastra/files/58148845000109_Estoque_PICPAY FGTS FIDC_001.csv
#    VALOR_NOMINAL  VALOR_PRESENTE  VALOR_AQUISICAO  NU_DOCUMENTO
# 0         169.67          101.16            99.94     106096977
# 1          84.84           40.74            40.25     106096977
# 2          55.68           52.08            51.44     106135870
# 3           5.63            1.79             1.77     106135984
# 4         160.27          147.19           145.37     106136007

# %%
len(df["NU_DOCUMENTO"].unique())
# Out:
# 1009934
